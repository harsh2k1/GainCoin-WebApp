# %%
import pandas as pd

# %%
df = pd.read_csv('coin_Bitcoin.csv')
df.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
df.shape
# Out:
# (2991, 10)

# %%
df.dtypes
# Out:
# SNo            int64
# Name          object
# Symbol        object
# Date          object
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Marketcap    float64
# dtype: object

# %%
for i in range(df.shape[0]):
    df.loc[i,'Date'] = df['Date'][i][:10]

# %%
df['Date'][:5]
# Out:
# 0    2013-04-29
# 1    2013-04-30
# 2    2013-05-01
# 3    2013-05-02
# 4    2013-05-03
# Name: Date, dtype: object

# %%
df.tail()
# Out:
#        SNo     Name Symbol        Date          High           Low  \
# 2986  2987  Bitcoin    BTC  2021-07-02  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 2986  33549.600177  33897.048590  3.872897e+10  6.354508e+11
# 2987  33854.421362  34668.548402  2.438396e+10  6.499397e+11
# 2988  34665.564866  35287.779766  2.492431e+10  6.615748e+11
# 2989  35284.344430  33746.002456  2.672155e+10  6.326962e+11
# 2990  33723.509655  34235.193451  2.650126e+10  6.418992e+11

# %%
price = list(df['Close'].tail(365))

# %%
df['24 DMA'] = df['Close'].rolling(window=24).mean()

# %%
df['50 DMA'] = df['Close'].rolling(window= 50).mean()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(13,8))
df['Close'].plot()
df['24 DMA'].plot()
df['50 DMA'].plot()
# Out:
# <AxesSubplot:>

# %%
DMA24 = list(df['24 DMA'].tail(365))
DMA50 = list(df['50 DMA'].tail(365))

# %%
date = list(df['Date'].tail(365))

# %%
date
# Out:
# ['2020-07-07 23:59:59',
#  '2020-07-08 23:59:59',
#  '2020-07-09 23:59:59',
#  '2020-07-10 23:59:59',
#  '2020-07-11 23:59:59',
#  '2020-07-12 23:59:59',
#  '2020-07-13 23:59:59',
#  '2020-07-14 23:59:59',
#  '2020-07-15 23:59:59',
#  '2020-07-16 23:59:59',
#  '2020-07-17 23:59:59',
#  '2020-07-18 23:59:59',
#  '2020-07-19 23:59:59',
#  '2020-07-20 23:59:59',
#  '2020-07-21 23:59:59',
#  '2020-07-22 23:59:59',
#  '2020-07-23 23:59:59',
#  '2020-07-24 23:59:59',
#  '2020-07-25 23:59:59',
#  '2020-07-26 23:59:59',
#  '2020-07-27 23:59:59',
#  '2020-07-28 23:59:59',
#  '2020-07-29 23:59:59',
#  '2020-07-30 23:59:59',
#  '2020-07-31 23:59:59',
#  '2020-08-01 23:59:59',
#  '2020-08-02 23:59:59',
#  '2020-08-03 23:59:59',
#  '2020-08-04 23:59:59',
#  '2020-08-05 23:59:59',
#  '2020-08-06 23:59:59',
#  '2020-08-07 23:59:59',
#  '2020-08-08 23:59:59',
#  '2020-08-09 23:59:59',
#  '2020-08-10 23:59:59',
#  '2020-08-11 23:59:59',
#  '2020-08-12 23:59:59',
#  '2020-08-13 23:59:59',
# ...
